# %%
import pandas as pd
from pathlib import Path
import csv
import operator
import json
from os import listdir
from pprint import pprint

# %%
queries = {
    'bostonglobe': ['science', 'science_extended'],
    'chicago': ['science'],
    'foxnews': ['science'],
    'theguardian': ['science'],
    'iflscience': [],
    'latimes': ['science'],
    'nytimes': ['science'],
    'sfchronicle': ['science'],
    'slate': ['bad_astronomy', 'climate_desk', 'future_tense', 'health_and_science'],
    'theglobeandmail': ['science'],
    'washingtonpost': ['animalia', 'energy-environment', 'speaking-of-science', 'to-your-health'],
    'wired': ['science']
}

news_short_altmetric = {
    'bostonglobe': ['The Boston Globe'],
    'chicago': ['Chicago Sun-Times'],
    'foxnews': ['FOX News'],
    'theguardian': ['The Guardian'],
    'iflscience': [],
    'latimes': ['LA Times'],
    'nytimes': ['New York Times'],
    'sfchronicle': ['San Francisco Chronicle'],
    'slate': ['Slate Magazine', 'Slate France'],
    'theglobeandmail': ['The Globe and Mail'],
    'washingtonpost': ['Washington Post'],
    'wired': ['Wired.it', 'Wired.com', 'Wired.co.uk']
}

news_altmetric_short = {}
for a, ss in news_short_altmetric.items():
    for s in ss:
        news_altmetric_short[s] = a

# %%
news_altmetric_short
# Out:
# {'Chicago Sun-Times': 'chicago',
#  'FOX News': 'foxnews',
#  'LA Times': 'latimes',
#  'New York Times': 'nytimes',
#  'San Francisco Chronicle': 'sfchronicle',
#  'Slate France': 'slate',
#  'Slate Magazine': 'slate',
#  'The Boston Globe': 'bostonglobe',
#  'The Globe and Mail': 'theglobeandmail',
#  'The Guardian': 'theguardian',
#  'Washington Post': 'washingtonpost',
#  'Wired.co.uk': 'wired',
#  'Wired.com': 'wired',
#  'Wired.it': 'wired'}

# %%
queries = pd.read_csv("../../data/queries.csv", index_col="id")
queries.head()
# Out:
#                                query            venue_name  venue_short  \
# id
# 1   bostonglobe AND science_extended      The Boston Globe  bostonglobe
# 2            bostonglobe AND science      The Boston Globe  bostonglobe
# 3   chicago AND suntimes AND science  The Chicago Suntimes      chicago
# 4                foxnews AND science              FOX News      foxnews
# 5               guardian AND science          The Guardian  theguardian
#
#       relevant_terms  found_tweets
# id
# 1   science_extended          2287
# 2            science         29963
# 3            science          2003
# 4            science        431310
# 5            science        130078

# %%
queries.groupby("venue_short")['relevant_terms'].apply(list)
# Out:
# venue_short
# bostonglobe                              [science_extended, science]
# chicago                                                    [science]
# foxnews                                                    [science]
# iflscience                                                     [nan]
# latimes                                                    [science]
# nytimes                                                    [science]
# sfchronicle                                                [science]
# slate              [bad_astronomy, climate_desk, future_tense, he...
# theglobeandmail                                            [science]
# theguardian                                                [science]
# washingtonpost     [animalia, energy-environment, speaking-of-sci...
# wired                                                      [science]
# Name: relevant_terms, dtype: object

# %%
queries.groupby("venue_name")['venue_short'].unique()
# Out:
# venue_name
# FOX News                        [foxnews]
# IFLScience                   [iflscience]
# SF Chronicle                [sfchronicle]
# Slate                             [slate]
# The Boston Globe            [bostonglobe]
# The Chicago Suntimes            [chicago]
# The Globe and Mail      [theglobeandmail]
# The Guardian                [theguardian]
# The LA Times                    [latimes]
# The NY Times                    [nytimes]
# The Washington Post      [washingtonpost]
# Wired                             [wired]
# Name: venue_short, dtype: object

# %%
data_dir = Path("../../data/")

all_tweets_dir = data_dir / "all_tweets"
selected_tweets_dir = data_dir / "refetched_tweets"
urls_dir = data_dir / "twitter_urls"
urls_cleaned_dir = data_dir / "twitter_urls_cleaned"

# %%
f = "chicago AND suntimes AND science.csv"
df = pd.read_csv(all_tweets_dir / f, index_col="tweet_id")
df2 = pd.read_csv(selected_tweets_dir / f, index_col="tweet_id")

# %%
cols = ['entities', 'quoted_status_id', 'retweeted_status_id']
for col in cols:
    df2[col] = None

# %%
df2.drop(["retweet_id", "retweet_truncated"], axis=1, inplace=True)
for ix, row in df2.iterrows():
    tweet = json.loads(row['tweet'])
    df2.loc[ix, 'entities'] = str(tweet['entities'])
    df2.loc[ix, 'truncated'] = str(tweet['truncated'])
    if 'quoted_status_id_str' in tweet:
        df2.loc[ix, 'quoted_status_id'] = tweet['quoted_status_id_str']
    if 'retweeted_status' in tweet:
        df2.loc[ix, 'retweeted_status_id'] = tweet['retweeted_status']['id_str']
df2.drop("tweet", axis=1)
# Out:
#                               posted_on truncated  refetched  \
# tweet_id
# 794830803037519876  2016-11-05 09:16:45     False      False
# 794830803037519876  2016-11-05 09:16:45     False      False
# 794830803037519876  2016-11-05 09:16:45     False      False
# 794846955365105664  2016-11-05 10:20:56     False      False
# 795006492189528064  2016-11-05 20:54:52     False      False
# 797141624199315456  2016-11-11 18:19:08     False      False
# 797142522174717953  2016-11-11 18:22:42     False       True
# 798616236930187264  2016-11-15 19:58:43      True      False
# 800326942402580480  2016-11-20 13:16:27     False       True
# 800362813701111808  2016-11-20 15:38:59     False      False
# 800375449243308032  2016-11-20 16:29:12     False      False
# 800395503707910145  2016-11-20 17:48:53     False      False
# 800410304664506368  2016-11-20 18:47:42     False      False
# 802523356742434817  2016-11-26 14:44:13     False      False
# 802528623399960576  2016-11-26 15:05:08     False      False
# 804044007500197888  2016-11-30 19:26:44     False       True
# 804046900383072256  2016-11-30 19:38:14     False      False
# 804053777024053249  2016-11-30 20:05:33     False      False
# 804061278239125504  2016-11-30 20:35:22     False      False
# 804061291828641793  2016-11-30 20:35:25     False      False
# 804061298191429633  2016-11-30 20:35:26     False      False
# 804061516135886848  2016-11-30 20:36:18     False      False
# 804061967463882753  2016-11-30 20:38:06     False      False
# 804062083423883268  2016-11-30 20:38:34     False      False
# 804062322507599872  2016-11-30 20:39:31     False      False
# 804065005301731328  2016-11-30 20:50:10     False      False
# 804065229210423296  2016-11-30 20:51:04     False      False
# 804065245417250816  2016-11-30 20:51:07     False      False
# 804074689035276288  2016-11-30 21:28:39     False      False
# 804091635860578304  2016-11-30 22:35:59     False      False
# ...                                 ...       ...        ...
# 899813525131976705  2017-08-22 02:00:36     False      False
# 899814814566014976  2017-08-22 02:05:44     False      False
# 900082914607509504                                                NaN
# 900082917094727680                                                NaN
# 900089066208854017                                                NaN
# 900123413565632512                                                NaN
# 900131766710808577                                                NaN
# 900139644263837697                                                NaN
# 900313190097051648                                                NaN
# 900389908514095109                                                NaN
# 900566942641078273                                                NaN
# 900844412573495297                                                NaN
# 900869351183704064                                                NaN
#
#                                                              entities  \
# tweet_id
# 794830803037519876  {'user_mentions': [], 'urls': [{'expanded_url'...
# 794830803037519876  {'user_mentions': [], 'urls': [{'expanded_url'...
# 794830803037519876  {'user_mentions': [], 'urls': [{'expanded_url'...
# 794846955365105664  {'user_mentions': [{'name': 'Pat Kiernan', 'in...
# 795006492189528064  {'user_mentions': [{'name': 'Pat Kiernan', 'in...
# 797141624199315456  {'user_mentions': [], 'urls': [{'expanded_url'...
# 797142522174717953  {'user_mentions': [], 'media': [{'media_url_ht...
# 798616236930187264  {'user_mentions': [{'name': 'Jordan Owen', 'in...
# 800326942402580480  {'user_mentions': [{'name': 'ACS PMSE Division...
# 800362813701111808  {'user_mentions': [{'name': 'ACS PMSE Division...
# 800375449243308032  {'user_mentions': [{'name': 'ACS PMSE Division...
# 800395503707910145  {'user_mentions': [{'name': 'ACS PMSE Division...
# 800410304664506368  {'user_mentions': [{'name': 'ACS PMSE Division...
# 802523356742434817  {'user_mentions': [{'name': 'Lincoln Park Zoo'...
# 802528623399960576  {'user_mentions': [{'name': 'Patrick Muller', ...
# 804044007500197888  {'user_mentions': [], 'media': [{'media_url_ht...
# 804046900383072256  {'user_mentions': [], 'media': [{'sizes': {'la...
# 804053777024053249  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804061278239125504  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804061291828641793  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804061298191429633  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804061516135886848  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804061967463882753  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804062083423883268  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804062322507599872  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804065005301731328  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804065229210423296  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804065245417250816  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804074689035276288  {'user_mentions': [], 'urls': [{'expanded_url'...
# 804091635860578304  {'user_mentions': [], 'urls': [{'expanded_url'...
# ...                                                               ...
# 899813525131976705  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 899814814566014976  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 899816605470908419  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 899818503087300609  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 899823306961862658  {'user_mentions': [{'name': 'Rep. Pramila Jaya...
# 899827591019974656  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 899836088021270528  {'user_mentions': [{'name': 'Rep. Pramila Jaya...
# 899843120535359488  {'user_mentions': [{'name': 'Thomas Frisbie', ...
# 899964060351025153  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 899970345947607041  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 900007020358766593  {'user_mentions': [], 'media': [{'media_url_ht...
# 900007921056133120  {'user_mentions': [{'name': 'Chicago Sun-Times...
# 900008572276355072  {'user_mentions': [{'name': 'Chicago Sun-Times...
# 900012408248389634  {'user_mentions': [{'name': 'Chicago Sun-Times...
# 900020156935569409  {'user_mentions': [], 'media': [{'media_url_ht...
# 900026047059578880  {'user_mentions': [], 'urls': [{'expanded_url'...
# 900046183275606016  {'user_mentions': [{'name': 'Planned Parenthoo...
# 900047639055654912  {'user_mentions': [], 'urls': [{'expanded_url'...
# 900070479888879617  {'user_mentions': [{'name': 'Chicago Sun-Times...
# 900082914607509504  {'user_mentions': [], 'urls': [{'expanded_url'...
# 900082917094727680  {'user_mentions': [], 'urls': [{'expanded_url'...
# 900089066208854017  {'user_mentions': [{'name': 'Chicago Sun-Times...
# 900123413565632512  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 900131766710808577  {'user_mentions': [], 'urls': [{'expanded_url'...
# 900139644263837697  {'user_mentions': [{'name': 'Emily Atkin', 'in...
# 900313190097051648  {'user_mentions': [{'name': 'Chicago Sun-Times...
# 900389908514095109  {'user_mentions': [{'name': 'C. S. Prakash', '...
# 900566942641078273  {'user_mentions': [{'name': 'C. S. Prakash', '...
# 900844412573495297  {'user_mentions': [{'name': 'Daniel Biss', 'in...
# 900869351183704064  {'user_mentions': [{'name': 'Chicago Sun-Times...
#
#                    retweeted_status_id quoted_status_id
# tweet_id
# 794830803037519876                 NaN              NaN
# 794830803037519876                 NaN              NaN
# 794830803037519876                 NaN              NaN
# 794846955365105664  794830803037519876              NaN
# 795006492189528064  794830803037519876              NaN
# 797141624199315456                 NaN              NaN
# 797142522174717953                 NaN              NaN
# 798616236930187264                 NaN              NaN
# 800326942402580480                 NaN              NaN
# 800362813701111808  800326942402580480              NaN
# 800375449243308032  800326942402580480              NaN
# 800395503707910145  800326942402580480              NaN
# 800410304664506368  800326942402580480              NaN
# 802523356742434817                 NaN              NaN
# 802528623399960576  802523356742434817              NaN
# 804044007500197888                 NaN              NaN
# 804046900383072256                 NaN              NaN
# 804053777024053249                 NaN              NaN
# 804061278239125504                 NaN              NaN
# 804061291828641793                 NaN              NaN
# 804061298191429633                 NaN              NaN
# 804061516135886848                 NaN              NaN
# 804061967463882753                 NaN              NaN
# 804062083423883268                 NaN              NaN
# 804062322507599872                 NaN              NaN
# 804065005301731328                 NaN              NaN
# 804065229210423296                 NaN              NaN
# 804065245417250816                 NaN              NaN
# 804074689035276288                 NaN              NaN
# 804091635860578304                 NaN              NaN
# ...                                ...              ...
# 899813525131976705  899612049709252608              NaN
# 899814814566014976  899612049709252608              NaN
# 899816605470908419  899612049709252608              NaN
# 899818503087300609  899612049709252608              NaN
# 899823306961862658  899697619647070208              NaN
# 899827591019974656  899612049709252608              NaN
# 899836088021270528  899697619647070208              NaN
# 899843120535359488  899575430600151040              NaN
# 899964060351025153  899612049709252608              NaN
# 899970345947607041  899612049709252608              NaN
# 900007020358766593                 NaN              NaN
# 900007921056133120  900007020358766593              NaN
# 900008572276355072  900007020358766593              NaN
# 900012408248389634  900007020358766593              NaN
# 900020156935569409                 NaN              NaN
# 900026047059578880                 NaN              NaN
# 900046183275606016  899665978367332352              NaN
# 900047639055654912                 NaN              NaN
# 900070479888879617                 NaN              NaN
# 900082914607509504                 NaN              NaN
# 900082917094727680                 NaN              NaN
# 900089066208854017  900007020358766593              NaN
# 900123413565632512  899612049709252608              NaN
# 900131766710808577                 NaN              NaN
# 900139644263837697  899646066080890880              NaN
# 900313190097051648                 NaN              NaN
# 900389908514095109  899007668110721024              NaN
# 900566942641078273  899007668110721024              NaN
# 900844412573495297  899612049709252608              NaN
# 900869351183704064                 NaN              NaN
#
# [834 rows x 7 columns]
